# %%
import pymysql
from pandas import DataFrame
import pandas as pd 

host   = 'villagebikesdb.c2v2pmaab8cg.us-east-2.rds.amazonaws.com'
port   = 3306
user   = 'ssk'
passwd = 'villagebikes'
db     = 'VillageBikesDB'

cnx    = pymysql.connect(host=host, port=port, user=user, passwd=passwd, db=db)
cur    = cnx.cursor()

query  = """SELECT * FROM weatherData"""
cur.execute(query)

field_names = [i[0] for i in cur.description]
get_data = [xx for xx in cur]

cur.close()
cnx.close()

df1 = DataFrame(get_data)
df1.columns = field_names
len(df1)
# Out:
# 1782

# %%
df1.head()
# Out:
#     timestamp  weather_id    main       description  temperature  humidity  \
# 0  1550743200         802  Clouds  scattered clouds       285.13      76.0
# 1  1550748600         802  Clouds  scattered clouds       285.64      71.0
# 2  1550750400         802  Clouds  scattered clouds       285.64      71.0
# 3  1550752200         802  Clouds  scattered clouds       285.64      66.0
# 4  1550761200         803  Clouds     broken clouds       286.15      62.0
#
#    wind_speed
# 0         3.1
# 1         5.1
# 2         6.2
# 3         5.7
# 4         8.2

# %%
df1 = df1.rename(index=str, columns={"timestamp": "last_update"})
df1.head()
# Out:
#    last_update  weather_id    main       description  temperature  humidity  \
# 0   1550743200         802  Clouds  scattered clouds       285.13      76.0
# 1   1550748600         802  Clouds  scattered clouds       285.64      71.0
# 2   1550750400         802  Clouds  scattered clouds       285.64      71.0
# 3   1550752200         802  Clouds  scattered clouds       285.64      66.0
# 4   1550761200         803  Clouds     broken clouds       286.15      62.0
#
#    wind_speed
# 0         3.1
# 1         5.1
# 2         6.2
# 3         5.7
# 4         8.2

# %%
import pymysql
from pandas import DataFrame
import pandas as pd 

host   = 'villagebikesdb.c2v2pmaab8cg.us-east-2.rds.amazonaws.com'
port   = 3306
user   = 'ssk'
passwd = 'villagebikes'
db     = 'VillageBikesDB'

cnx    = pymysql.connect(host=host, port=port, user=user, passwd=passwd, db=db)
cur    = cnx.cursor()

query  = """SELECT * FROM dynamicData"""
cur.execute(query)

field_names = [i[0] for i in cur.description]
get_data = [xx for xx in cur]

cur.close()
cnx.close()

df2 = DataFrame(get_data)
df2.columns = field_names
len(df2)
# Out:
# 652359

# %%
df2.head()
# Out:
#    number                name status  bike_stands  available_bikes  \
# 0       2  BLESSINGTON STREET   OPEN           20                3
# 1       2  BLESSINGTON STREET   OPEN           20                3
# 2       2  BLESSINGTON STREET   OPEN           20                3
# 3       2  BLESSINGTON STREET   OPEN           20                4
# 4       2  BLESSINGTON STREET   OPEN           20                4
#
#    available_stands    last_update  banking
# 0                17  1550767646000        1
# 1                17  1550768255000        1
# 2                17  1550768863000        1
# 3                16  1550769472000        1
# 4                16  1550769841000        1

# %%
len(df2)
# Out:
# 652359

# %%
df1.dtypes
# Out:
# last_update      int64
# weather_id       int64
# main            object
# description     object
# temperature    float64
# humidity       float64
# wind_speed     float64
# dtype: object

# %%
df2.dtypes
# Out:
# number               int64
# name                object
# status              object
# bike_stands          int64
# available_bikes      int64
# available_stands     int64
# last_update          int64
# banking              int64
# dtype: object

# %%
df1 = df1.sort_values(by=['last_update'])

# %%
df2 = df2.sort_values(by=['last_update'])

# %%
df2.head()
# Out:
#         number                        name status  bike_stands  \
# 171294      30        PARNELL SQUARE NORTH   OPEN           20
# 601122     105  GRANGEGORMAN LOWER (NORTH)   OPEN           36
# 332213      55                HATCH STREET   OPEN           36
# 558038      95              ROYAL HOSPITAL   OPEN           40
# 251850      41            HARCOURT TERRACE   OPEN           20
#
#         available_bikes  available_stands    last_update  banking
# 171294                0                20  1550767501000        1
# 601122                9                27  1550767505000        0
# 332213                0                36  1550767511000        0
# 558038                5                35  1550767517000        1
# 251850                1                19  1550767525000        0

# %%
df3 = pd.merge_asof(df2,df1, on='last_update', direction='nearest')
df3
# Out:
#         number                               name status  bike_stands  \
# 0           30               PARNELL SQUARE NORTH   OPEN           20
# 1          105         GRANGEGORMAN LOWER (NORTH)   OPEN           36
# 2           55                       HATCH STREET   OPEN           36
# 3           95                     ROYAL HOSPITAL   OPEN           40
# 4           41                   HARCOURT TERRACE   OPEN           20
# 5          113               MERRION SQUARE SOUTH   OPEN           40
# 6           61                    HARDWICKE PLACE   OPEN           25
# 7           82                        MOUNT BROWN   OPEN           22
# 8           79                 ECCLES STREET EAST   OPEN           27
# 9           13            FITZWILLIAM SQUARE WEST   OPEN           30
# 10          90                      BENSON STREET   OPEN           40
# 11           2                 BLESSINGTON STREET   OPEN           20
# 12          94         HEUSTON STATION (CAR PARK)   OPEN           40
# 13         106                      RATHDOWN ROAD   OPEN           40
# 14         110                  PHIBSBOROUGH ROAD   OPEN           40
# 15          81       ST. JAMES HOSPITAL (CENTRAL)   OPEN           40
# 16         111               MOUNTJOY SQUARE EAST   OPEN           40
# 17          10                        DAME STREET   OPEN           16
# 18           3                      BOLTON STREET   OPEN           20
# 19         108                      AVONDALE ROAD   OPEN           40
# 20         102                        WESTERN WAY   OPEN           40
# 21          84                    BROOKFIELD ROAD   OPEN           30
# 22          15                   HARDWICKE STREET   OPEN           16
# 23          76                MARKET STREET SOUTH   OPEN           38
# 24          52                   YORK STREET EAST   OPEN           32
# 25          29                  ORMOND QUAY UPPER   OPEN           29
# 26           7                        HIGH STREET   OPEN           29
# 27          87            COLLINS BARRACKS MUSEUM   OPEN           38
# 28         109            BUCKINGHAM STREET LOWER   OPEN           29
# 29          96                    KILMAINHAM LANE   OPEN           30
# ...        ...                                ...    ...          ...
# 652329      95                     ROYAL HOSPITAL   OPEN           40
# 652330     100             HEUSTON BRIDGE (SOUTH)   OPEN           25
# 652331      92             HEUSTON BRIDGE (NORTH)   OPEN           40
# 652332       9                   EXCHEQUER STREET   OPEN           24
# 652333      38                      TALBOT STREET   OPEN           40
# 652334      65                  CONVENTION CENTRE   OPEN           40
# 652335      69                   GRAND CANAL DOCK   OPEN           40
# 652336      76                MARKET STREET SOUTH   OPEN           38
# 652337      28               MOUNTJOY SQUARE WEST   OPEN           30
# 652338      51                   YORK STREET WEST   OPEN           40
# 652339      68                       HANOVER QUAY   OPEN           40
# 652340      22                    TOWNSEND STREET   OPEN           20
# 652341      64                    SANDWITH STREET   OPEN           40
# 652342      83                         EMMET ROAD   OPEN           40
# 652343       9                   EXCHEQUER STREET   OPEN           24
# 652344      13            FITZWILLIAM SQUARE WEST   OPEN           30
# 652345      29                  ORMOND QUAY UPPER   OPEN           29
# 652346     107                   CHARLEVILLE ROAD   OPEN           40
# 652347      69                   GRAND CANAL DOCK   OPEN           40
# 652348     114              WILTON TERRACE (PARK)   OPEN           40
# 652349     101                  KING STREET NORTH   OPEN           30
# 652350      17                        GOLDEN LANE   OPEN           20
# 652351      82                        MOUNT BROWN   OPEN           22
# 652352      60                NORTH CIRCULAR ROAD   OPEN           30
# 652353      67                          THE POINT   OPEN           40
# 652354      35                         SMITHFIELD   OPEN           30
# 652355      45                     DEVERELL PLACE   OPEN           30
# 652356     112  NORTH CIRCULAR ROAD (O'CONNELL'S)   OPEN           30
# 652357      14                FOWNES STREET UPPER   OPEN           30
# 652358      72                   JOHN STREET WEST   OPEN           31
#
#         available_bikes  available_stands    last_update  banking  weather_id  \
# 0                     0                20  1550767501000        1         802
# 1                     9                27  1550767505000        0         802
# 2                     0                36  1550767511000        0         802
# 3                     5                35  1550767517000        1         802
# 4                     1                19  1550767525000        0         802
# 5                    33                 7  1550767532000        1         802
# 6                     0                25  1550767541000        1         802
# 7                     0                22  1550767556000        0         802
# 8                     0                27  1550767591000        0         802
# 9                    18                11  1550767628000        0         802
# 10                   19                21  1550767640000        0         802
# 11                    3                17  1550767646000        1         802
# 12                    0                40  1550767678000        0         802
# 13                    3                37  1550767691000        0         802
# 14                    1                39  1550767700000        0         802
# 15                    0                40  1550767702000        0         802
# 16                    2                38  1550767708000        1         802
# 17                    0                16  1550767739000        1         802
# 18                    0                20  1550767744000        0         802
# 19                    1                38  1550767750000        0         802
# 20                    7                33  1550767765000        0         802
# 21                    1                29  1550767768000        0         802
# 22                    0                16  1550767769000        0         802
# 23                    5                33  1550767771000        0         802
# 24                    2                30  1550767774000        0         802
# 25                    0                29  1550767790000        1         802
# 26                    0                29  1550767791000        1         802
# 27                    1                37  1550767823000        1         802
# 28                    7                22  1550767829000        0         802
# 29                    5                25  1550767843000        0         802
# ...                 ...               ...            ...      ...         ...
# 652329               20                20  1552740819000        1         802
# 652330               20                 5  1552740823000        0         802
# 652331               20                20  1552740825000        0         802
# 652332               18                 6  1552740826000        0         802
# 652333               38                 2  1552740830000        0         802
# 652334                6                34  1552740837000        1         802
# 652335               15                25  1552740841000        0         802
# 652336               23                15  1552740842000        0         802
# 652337               15                15  1552740850000        0         802
# 652338               20                20  1552740854000        0         802
# 652339               17                23  1552740854000        1         802
# 652340               20                 0  1552740856000        0         802
# 652341               14                26  1552740857000        1         802
# 652342                5                35  1552740862000        0         802
# 652343               18                 6  1552740864000        0         802
# 652344                9                21  1552740869000        0         802
# 652345               13                16  1552740873000        1         802
# 652346                5                35  1552740876000        1         802
# 652347               15                25  1552740876000        0         802
# 652348                8                32  1552740877000        1         802
# 652349                0                30  1552740881000        0         802
# 652350                4                16  1552740881000        0         802
# 652351                4                18  1552740887000        0         802
# 652352               11                19  1552740895000        0         802
# 652353                7                33  1552740897000        0         802
# 652354                2                28  1552740897000        0         802
# 652355               30                 0  1552740897000        0         802
# 652356                5                25  1552740901000        0         802
# 652357               21                 9  1552740901000        0         802
# 652358               18                13  1552740902000        0         802
#
#           main       description  temperature  humidity  wind_speed
# 0       Clouds  scattered clouds       283.04      81.0         2.1
# 1       Clouds  scattered clouds       283.04      81.0         2.1
# 2       Clouds  scattered clouds       283.04      81.0         2.1
# 3       Clouds  scattered clouds       283.04      81.0         2.1
# 4       Clouds  scattered clouds       283.04      81.0         2.1
# 5       Clouds  scattered clouds       283.04      81.0         2.1
# 6       Clouds  scattered clouds       283.04      81.0         2.1
# 7       Clouds  scattered clouds       283.04      81.0         2.1
# 8       Clouds  scattered clouds       283.04      81.0         2.1
# 9       Clouds  scattered clouds       283.04      81.0         2.1
# 10      Clouds  scattered clouds       283.04      81.0         2.1
# 11      Clouds  scattered clouds       283.04      81.0         2.1
# 12      Clouds  scattered clouds       283.04      81.0         2.1
# 13      Clouds  scattered clouds       283.04      81.0         2.1
# 14      Clouds  scattered clouds       283.04      81.0         2.1
# 15      Clouds  scattered clouds       283.04      81.0         2.1
# 16      Clouds  scattered clouds       283.04      81.0         2.1
# 17      Clouds  scattered clouds       283.04      81.0         2.1
# 18      Clouds  scattered clouds       283.04      81.0         2.1
# 19      Clouds  scattered clouds       283.04      81.0         2.1
# 20      Clouds  scattered clouds       283.04      81.0         2.1
# 21      Clouds  scattered clouds       283.04      81.0         2.1
# 22      Clouds  scattered clouds       283.04      81.0         2.1
# 23      Clouds  scattered clouds       283.04      81.0         2.1
# 24      Clouds  scattered clouds       283.04      81.0         2.1
# 25      Clouds  scattered clouds       283.04      81.0         2.1
# 26      Clouds  scattered clouds       283.04      81.0         2.1
# 27      Clouds  scattered clouds       283.04      81.0         2.1
# 28      Clouds  scattered clouds       283.04      81.0         2.1
# 29      Clouds  scattered clouds       283.04      81.0         2.1
# ...        ...               ...          ...       ...         ...
# 652329  Clouds  scattered clouds       283.04      81.0         2.1
# 652330  Clouds  scattered clouds       283.04      81.0         2.1
# 652331  Clouds  scattered clouds       283.04      81.0         2.1
# 652332  Clouds  scattered clouds       283.04      81.0         2.1
# 652333  Clouds  scattered clouds       283.04      81.0         2.1
# 652334  Clouds  scattered clouds       283.04      81.0         2.1
# 652335  Clouds  scattered clouds       283.04      81.0         2.1
# 652336  Clouds  scattered clouds       283.04      81.0         2.1
# 652337  Clouds  scattered clouds       283.04      81.0         2.1
# 652338  Clouds  scattered clouds       283.04      81.0         2.1
# 652339  Clouds  scattered clouds       283.04      81.0         2.1
# 652340  Clouds  scattered clouds       283.04      81.0         2.1
# 652341  Clouds  scattered clouds       283.04      81.0         2.1
# 652342  Clouds  scattered clouds       283.04      81.0         2.1
# 652343  Clouds  scattered clouds       283.04      81.0         2.1
# 652344  Clouds  scattered clouds       283.04      81.0         2.1
# 652345  Clouds  scattered clouds       283.04      81.0         2.1
# 652346  Clouds  scattered clouds       283.04      81.0         2.1
# 652347  Clouds  scattered clouds       283.04      81.0         2.1
# 652348  Clouds  scattered clouds       283.04      81.0         2.1
# 652349  Clouds  scattered clouds       283.04      81.0         2.1
# 652350  Clouds  scattered clouds       283.04      81.0         2.1
# 652351  Clouds  scattered clouds       283.04      81.0         2.1
# 652352  Clouds  scattered clouds       283.04      81.0         2.1
# 652353  Clouds  scattered clouds       283.04      81.0         2.1
# 652354  Clouds  scattered clouds       283.04      81.0         2.1
# 652355  Clouds  scattered clouds       283.04      81.0         2.1
# 652356  Clouds  scattered clouds       283.04      81.0         2.1
# 652357  Clouds  scattered clouds       283.04      81.0         2.1
# 652358  Clouds  scattered clouds       283.04      81.0         2.1
#
# [652359 rows x 14 columns]

# %%
df3['last_update'] = pd.to_datetime(df3.last_update, unit='ms')

# %%
df3.to_csv('full_dataframe.csv')
