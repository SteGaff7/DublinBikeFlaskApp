# %%
# Library Imports.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Allows plots to appear directly in the notebook.
# %matplotlib inline

from patsy import dmatrices
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import cross_validate

# %%
class stationPrediciton():
    
    def __init__(self, number, name, totalBikes): # Initialises the stations
        self.name = name
        self.number = number
        self.totalBikes = totalBikes
        self.model = dict() # Has Key:Value pair = {Feature: co-efficient}
        
    def prediction(self, time, day, weather): # This will provide return the predicition
        prediction = 0 # Intialise the prediction to 0
        for k , v in self.model: # Loops through the dictionary and extracts key and value
            if k == 'time':
                prediction += v*time
            elif k == 'day':
                prediciton += v*day
            elif k == 'weather':
                predicition += v*weather
            else:
                predition += v # This condition covers the bias or (w_0)
            
    def train(self, availableBikes, time, day, weather): # This will train the model       
        pass

# %%
df = pd.read_csv('full_dataframe.csv')
df
# Out:
#         Unnamed: 0  number                               name status  \
# 0                0      30               PARNELL SQUARE NORTH   OPEN
# 1                1     105         GRANGEGORMAN LOWER (NORTH)   OPEN
# 2                2      55                       HATCH STREET   OPEN
# 3                3      95                     ROYAL HOSPITAL   OPEN
# 4                4      41                   HARCOURT TERRACE   OPEN
# 5                5     113               MERRION SQUARE SOUTH   OPEN
# 6                6      61                    HARDWICKE PLACE   OPEN
# 7                7      82                        MOUNT BROWN   OPEN
# 8                8      79                 ECCLES STREET EAST   OPEN
# 9                9      13            FITZWILLIAM SQUARE WEST   OPEN
# 10              10      90                      BENSON STREET   OPEN
# 11              11       2                 BLESSINGTON STREET   OPEN
# 12              12      94         HEUSTON STATION (CAR PARK)   OPEN
# 13              13     106                      RATHDOWN ROAD   OPEN
# 14              14     110                  PHIBSBOROUGH ROAD   OPEN
# 15              15      81       ST. JAMES HOSPITAL (CENTRAL)   OPEN
# 16              16     111               MOUNTJOY SQUARE EAST   OPEN
# 17              17      10                        DAME STREET   OPEN
# 18              18       3                      BOLTON STREET   OPEN
# 19              19     108                      AVONDALE ROAD   OPEN
# 20              20     102                        WESTERN WAY   OPEN
# 21              21      84                    BROOKFIELD ROAD   OPEN
# 22              22      15                   HARDWICKE STREET   OPEN
# 23              23      76                MARKET STREET SOUTH   OPEN
# 24              24      52                   YORK STREET EAST   OPEN
# 25              25      29                  ORMOND QUAY UPPER   OPEN
# 26              26       7                        HIGH STREET   OPEN
# 27              27      87            COLLINS BARRACKS MUSEUM   OPEN
# 28              28     109            BUCKINGHAM STREET LOWER   OPEN
# 29              29      96                    KILMAINHAM LANE   OPEN
# ...            ...     ...                                ...    ...
# 652329      652329      95                     ROYAL HOSPITAL   OPEN
# 652330      652330     100             HEUSTON BRIDGE (SOUTH)   OPEN
# 652331      652331      92             HEUSTON BRIDGE (NORTH)   OPEN
# 652332      652332       9                   EXCHEQUER STREET   OPEN
# 652333      652333      38                      TALBOT STREET   OPEN
# 652334      652334      65                  CONVENTION CENTRE   OPEN
# 652335      652335      69                   GRAND CANAL DOCK   OPEN
# 652336      652336      76                MARKET STREET SOUTH   OPEN
# 652337      652337      28               MOUNTJOY SQUARE WEST   OPEN
# 652336           38               23                15  2019-03-16 12:54:02
# 652337           30               15                15  2019-03-16 12:54:10
# 652338           40               20                20  2019-03-16 12:54:14
# 652339           40               17                23  2019-03-16 12:54:14
# 652340           20               20                 0  2019-03-16 12:54:16
# 652341           40               14                26  2019-03-16 12:54:17
# 652342           40                5                35  2019-03-16 12:54:22
# 652343           24               18                 6  2019-03-16 12:54:24
# 652344           30                9                21  2019-03-16 12:54:29
# 652345           29               13                16  2019-03-16 12:54:33
# 652346           40                5                35  2019-03-16 12:54:36
# 652347           40               15                25  2019-03-16 12:54:36
# 652348           40                8                32  2019-03-16 12:54:37
# 652349           30                0                30  2019-03-16 12:54:41
# 652350           20                4                16  2019-03-16 12:54:41
# 652351           22                4                18  2019-03-16 12:54:47
# 652352           30               11                19  2019-03-16 12:54:55
# 652353           40                7                33  2019-03-16 12:54:57
# 652354           30                2                28  2019-03-16 12:54:57
# 652355           30               30                 0  2019-03-16 12:54:57
# 652356           30                5                25  2019-03-16 12:55:01
# 652357           30               21                 9  2019-03-16 12:55:01
# 652358           31               18                13  2019-03-16 12:55:02
#
#         banking  weather_id    main       description  temperature  humidity  \
# 0             1         802  Clouds  scattered clouds       283.04      81.0
# 1             0         802  Clouds  scattered clouds       283.04      81.0
# 2             0         802  Clouds  scattered clouds       283.04      81.0
# 3             1         802  Clouds  scattered clouds       283.04      81.0
# 4             0         802  Clouds  scattered clouds       283.04      81.0
# 5             1         802  Clouds  scattered clouds       283.04      81.0
# 6             1         802  Clouds  scattered clouds       283.04      81.0
# 7             0         802  Clouds  scattered clouds       283.04      81.0
# 8             0         802  Clouds  scattered clouds       283.04      81.0
# 9             0         802  Clouds  scattered clouds       283.04      81.0
# 10            0         802  Clouds  scattered clouds       283.04      81.0
# 11            1         802  Clouds  scattered clouds       283.04      81.0
# 12            0         802  Clouds  scattered clouds       283.04      81.0
# 13            0         802  Clouds  scattered clouds       283.04      81.0
# 14            0         802  Clouds  scattered clouds       283.04      81.0
# 15            0         802  Clouds  scattered clouds       283.04      81.0
# 16            1         802  Clouds  scattered clouds       283.04      81.0
# 17            1         802  Clouds  scattered clouds       283.04      81.0
# 18            0         802  Clouds  scattered clouds       283.04      81.0
# 19            0         802  Clouds  scattered clouds       283.04      81.0
# 20            0         802  Clouds  scattered clouds       283.04      81.0
# 21            0         802  Clouds  scattered clouds       283.04      81.0
# 22            0         802  Clouds  scattered clouds       283.04      81.0
# 23            0         802  Clouds  scattered clouds       283.04      81.0
# 24            0         802  Clouds  scattered clouds       283.04      81.0
# 25            1         802  Clouds  scattered clouds       283.04      81.0
# 26            1         802  Clouds  scattered clouds       283.04      81.0
# 27            1         802  Clouds  scattered clouds       283.04      81.0
# 28            0         802  Clouds  scattered clouds       283.04      81.0
# 29            0         802  Clouds  scattered clouds       283.04      81.0
# ...         ...         ...     ...               ...          ...       ...
# 652329        1         802  Clouds  scattered clouds       283.04      81.0
# 652330        0         802  Clouds  scattered clouds       283.04      81.0
# 652331        0         802  Clouds  scattered clouds       283.04      81.0
# 652332        0         802  Clouds  scattered clouds       283.04      81.0
# 652333        0         802  Clouds  scattered clouds       283.04      81.0
# 652334        1         802  Clouds  scattered clouds       283.04      81.0
# 652335        0         802  Clouds  scattered clouds       283.04      81.0
# 652336        0         802  Clouds  scattered clouds       283.04      81.0
# 652337        0         802  Clouds  scattered clouds       283.04      81.0
# 652338        0         802  Clouds  scattered clouds       283.04      81.0
# 652339        1         802  Clouds  scattered clouds       283.04      81.0
# 652340        0         802  Clouds  scattered clouds       283.04      81.0
# 652341        1         802  Clouds  scattered clouds       283.04      81.0
# 652342        0         802  Clouds  scattered clouds       283.04      81.0
# 652343        0         802  Clouds  scattered clouds       283.04      81.0
# 652344        0         802  Clouds  scattered clouds       283.04      81.0
# 652345        1         802  Clouds  scattered clouds       283.04      81.0
# 652346        1         802  Clouds  scattered clouds       283.04      81.0
# 652347        0         802  Clouds  scattered clouds       283.04      81.0
# 652348        1         802  Clouds  scattered clouds       283.04      81.0
# 652349        0         802  Clouds  scattered clouds       283.04      81.0
# 652350        0         802  Clouds  scattered clouds       283.04      81.0
# 652351        0         802  Clouds  scattered clouds       283.04      81.0
# 652352        0         802  Clouds  scattered clouds       283.04      81.0
# 652353        0         802  Clouds  scattered clouds       283.04      81.0
# 652354        0         802  Clouds  scattered clouds       283.04      81.0
# 652355        0         802  Clouds  scattered clouds       283.04      81.0
# 652356        0         802  Clouds  scattered clouds       283.04      81.0
# 652357        0         802  Clouds  scattered clouds       283.04      81.0
# 652358        0         802  Clouds  scattered clouds       283.04      81.0
#
#         wind_speed
# 0              2.1
# 1              2.1
# 2              2.1
# 3              2.1
# 4              2.1
# 5              2.1
# 6              2.1
# 7              2.1
# 8              2.1
# 9              2.1
# 10             2.1
# 11             2.1
# 12             2.1
# 13             2.1
# 14             2.1
# 15             2.1
# 16             2.1
# 17             2.1
# 18             2.1
# 19             2.1
# 20             2.1
# 21             2.1
# 22             2.1
# 23             2.1
# 24             2.1
# 25             2.1
# 26             2.1
# 27             2.1
# 28             2.1
# 29             2.1
# ...            ...
# 652329         2.1
# 652330         2.1
# 652331         2.1
# 652332         2.1
# 652333         2.1
# 652334         2.1
# 652335         2.1
# 652336         2.1
# 652337         2.1
# 652338         2.1
# 652339         2.1
# 652340         2.1
# 652341         2.1
# 652342         2.1
# 652343         2.1
# 652344         2.1
# 652345         2.1
# 652346         2.1
# 652347         2.1
# 652348         2.1
# 652349         2.1
# 652350         2.1
# 652351         2.1
# 652352         2.1
# 652353         2.1
# 652354         2.1
# 652355         2.1
# 652356         2.1
# 652357         2.1
# 652358         2.1
#
# [652359 rows x 15 columns]

# %%
temp_df = df[['number', 'name', 'bike_stands']]
type(temp_df)
for index, row in temp_df.iterrows():
    number = row['number']
    name = row ['name']
    row = ['bike_stands']
    object_name = name.replace(" ", "_")
    object_name = stationPrediciton(number,name,row)
