# %%
import pymysql
from pandas import DataFrame
import pandas as pd 

host   = 'villagebikesdb.c2v2pmaab8cg.us-east-2.rds.amazonaws.com'
port   = 3306
user   = 'ssk'
passwd = 'villagebikes'
db     = 'VillageBikesDB'

cnx    = pymysql.connect(host=host, port=port, user=user, passwd=passwd, db=db)
cur    = cnx.cursor()

query  = """SELECT * FROM weatherData"""
cur.execute(query)

field_names = [i[0] for i in cur.description]
get_data = [xx for xx in cur]

cur.close()
cnx.close()

df1 = DataFrame(get_data)
df1.columns = field_names
len(df1)
# Out:
# 2257

# %%
df1['timestamp'] = pd.to_datetime(df1.timestamp,unit='s')

# %%
df1.head()
# Out:
#             timestamp  weather_id    main       description  temperature  \
# 0 2019-02-21 10:00:00         802  Clouds  scattered clouds       285.13
# 1 2019-02-21 11:30:00         802  Clouds  scattered clouds       285.64
# 2 2019-02-21 12:00:00         802  Clouds  scattered clouds       285.64
# 3 2019-02-21 12:30:00         802  Clouds  scattered clouds       285.64
# 4 2019-02-21 15:00:00         803  Clouds     broken clouds       286.15
#
#    humidity  wind_speed
# 0      76.0         3.1
# 1      71.0         5.1
# 2      71.0         6.2
# 3      66.0         5.7
# 4      62.0         8.2

# %%
df1 = df1.rename(index=str, columns={"timestamp": "last_update"})
df1.head()
# Out:
#           last_update  weather_id    main       description  temperature  \
# 0 2019-02-21 10:00:00         802  Clouds  scattered clouds       285.13
# 1 2019-02-21 11:30:00         802  Clouds  scattered clouds       285.64
# 2 2019-02-21 12:00:00         802  Clouds  scattered clouds       285.64
# 3 2019-02-21 12:30:00         802  Clouds  scattered clouds       285.64
# 4 2019-02-21 15:00:00         803  Clouds     broken clouds       286.15
#
#    humidity  wind_speed
# 0      76.0         3.1
# 1      71.0         5.1
# 2      71.0         6.2
# 3      66.0         5.7
# 4      62.0         8.2

# %%
import pymysql
from pandas import DataFrame
import pandas as pd 

host   = 'villagebikesdb.c2v2pmaab8cg.us-east-2.rds.amazonaws.com'
port   = 3306
user   = 'ssk'
passwd = 'villagebikes'
db     = 'VillageBikesDB'

cnx    = pymysql.connect(host=host, port=port, user=user, passwd=passwd, db=db)
cur    = cnx.cursor()

query  = """SELECT * FROM dynamicData LIMIT 500"""
cur.execute(query)

field_names = [i[0] for i in cur.description]
get_data = [xx for xx in cur]

cur.close()
cnx.close()

df2 = DataFrame(get_data)
df2.columns = field_names
len(df2)
# Out:
# 500

# %%
df2['last_update'] = pd.to_datetime(df2.last_update,unit='ms')

# %%
df2.head()
# Out:
#    number                name status  bike_stands  available_bikes  \
# 0       2  BLESSINGTON STREET   OPEN           20                3
# 1       2  BLESSINGTON STREET   OPEN           20                3
# 2       2  BLESSINGTON STREET   OPEN           20                3
# 3       2  BLESSINGTON STREET   OPEN           20                4
# 4       2  BLESSINGTON STREET   OPEN           20                4
#
#    available_stands         last_update  banking
# 0                17 2019-02-21 16:47:26        1
# 1                17 2019-02-21 16:57:35        1
# 2                17 2019-02-21 17:07:43        1
# 3                16 2019-02-21 17:17:52        1
# 4                16 2019-02-21 17:24:01        1

# %%
len(df2)
# Out:
# 500

# %%
df1.dtypes
# Out:
# last_update    datetime64[ns]
# weather_id              int64
# main                   object
# description            object
# temperature           float64
# humidity              float64
# wind_speed            float64
# dtype: object

# %%
df2.dtypes
# Out:
# number                       int64
# name                        object
# status                      object
# bike_stands                  int64
# available_bikes              int64
# available_stands             int64
# last_update         datetime64[ns]
# banking                      int64
# dtype: object

# %%
df1 = df1.sort_values(by=['last_update'])

# %%
df2 = df2.sort_values(by=['last_update'])

# %%
df2.head()
# Out:
#    number                name status  bike_stands  available_bikes  \
# 0       2  BLESSINGTON STREET   OPEN           20                3
# 1       2  BLESSINGTON STREET   OPEN           20                3
# 2       2  BLESSINGTON STREET   OPEN           20                3
# 3       2  BLESSINGTON STREET   OPEN           20                4
# 4       2  BLESSINGTON STREET   OPEN           20                4
#
#    available_stands         last_update  banking
# 0                17 2019-02-21 16:47:26        1
# 1                17 2019-02-21 16:57:35        1
# 2                17 2019-02-21 17:07:43        1
# 3                16 2019-02-21 17:17:52        1
# 4                16 2019-02-21 17:24:01        1

# %%
df3 = pd.merge_asof(df2,df1, on='last_update', direction='nearest')
df3
# Out:
#      number                name status  bike_stands  available_bikes  \
# 0         2  BLESSINGTON STREET   OPEN           20                3
# 1         2  BLESSINGTON STREET   OPEN           20                3
# 2         2  BLESSINGTON STREET   OPEN           20                3
# 3         2  BLESSINGTON STREET   OPEN           20                4
# 4         2  BLESSINGTON STREET   OPEN           20                4
# 5         2  BLESSINGTON STREET   OPEN           20                3
# 6         2  BLESSINGTON STREET   OPEN           20                3
# 7         2  BLESSINGTON STREET   OPEN           20                3
# 8         2  BLESSINGTON STREET   OPEN           20                3
# 9         2  BLESSINGTON STREET   OPEN           20                4
# 10        2  BLESSINGTON STREET   OPEN           20                4
# 11        2  BLESSINGTON STREET   OPEN           20                3
# 12        2  BLESSINGTON STREET   OPEN           20                3
# 13        2  BLESSINGTON STREET   OPEN           20                2
# 14        2  BLESSINGTON STREET   OPEN           20                2
# 15        2  BLESSINGTON STREET   OPEN           20                2
# 16        2  BLESSINGTON STREET   OPEN           20                3
# 17        2  BLESSINGTON STREET   OPEN           20                3
# 18        2  BLESSINGTON STREET   OPEN           20                3
# 19        2  BLESSINGTON STREET   OPEN           20                3
# 20        2  BLESSINGTON STREET   OPEN           20                2
# 21        2  BLESSINGTON STREET   OPEN           20                2
# 22        2  BLESSINGTON STREET   OPEN           20                3
# 23        2  BLESSINGTON STREET   OPEN           20                4
# 1       broken clouds       284.15      71.0         6.2
# 2       broken clouds       284.15      71.0         6.2
# 3       broken clouds       284.15      71.0         7.2
# 4       broken clouds       284.15      71.0         7.2
# 5       broken clouds       284.15      71.0         7.2
# 6       broken clouds       284.15      71.0         7.2
# 7       broken clouds       284.15      71.0         7.2
# 8       broken clouds       284.15      71.0         7.2
# 9       broken clouds       284.15      71.0         6.7
# 10      broken clouds       284.15      71.0         6.7
# 11      broken clouds       284.15      71.0         6.7
# 12      broken clouds       284.15      71.0         6.7
# 13      broken clouds       284.15      71.0         6.7
# 14      broken clouds       284.15      71.0         6.7
# 15      broken clouds       284.15      71.0         6.7
# 16      broken clouds       284.15      71.0         6.7
# 17      broken clouds       284.15      71.0         6.7
# 18      broken clouds       284.15      71.0         6.7
# 19      broken clouds       284.15      71.0         6.7
# 20      broken clouds       284.15      71.0         6.7
# 21      broken clouds       284.15      71.0         6.7
# 22      broken clouds       284.15      71.0         4.6
# 23      broken clouds       284.15      71.0         4.6
# 24      broken clouds       284.15      71.0         4.6
# 25      broken clouds       284.15      71.0         4.6
# 26      broken clouds       284.15      71.0         4.6
# 27      broken clouds       284.15      71.0         4.6
# 28      broken clouds       284.15      71.0         4.6
# 29      broken clouds       283.15      76.0         5.7
# ..                ...          ...       ...         ...
# 470     broken clouds       285.72      87.0         5.7
# 471     broken clouds       285.72      87.0         5.7
# 472     broken clouds       285.72      87.0         5.7
# 473     broken clouds       286.15      76.0         6.2
# 474     broken clouds       286.15      76.0         6.2
# 475     broken clouds       286.15      76.0         6.2
# 476     broken clouds       286.15      71.0         4.6
# 477     broken clouds       286.15      71.0         4.6
# 478     broken clouds       286.15      71.0         4.6
# 479     broken clouds       286.15      71.0         4.6
# 480     broken clouds       286.15      71.0         4.6
# 481     broken clouds       286.15      71.0         4.6
# 482     broken clouds       286.15      71.0         4.6
# 483     broken clouds       286.15      71.0         4.6
# 484     broken clouds       286.15      71.0         4.6
# 485     broken clouds       286.15      76.0         4.1
# 486     broken clouds       286.15      76.0         4.1
# 487     broken clouds       286.15      76.0         4.1
# 488     broken clouds       286.15      76.0         4.1
# 489     broken clouds       286.15      76.0         4.1
# 490     broken clouds       286.15      76.0         4.6
# 491     broken clouds       286.15      76.0         4.6
# 492     broken clouds       286.15      76.0         4.6
# 493     broken clouds       286.15      76.0         4.6
# 494     broken clouds       286.15      76.0         4.6
# 495     broken clouds       286.15      76.0         4.6
# 496     broken clouds       286.15      76.0         4.6
# 497  scattered clouds       286.58      67.0         4.6
# 498  scattered clouds       286.58      67.0         4.6
# 499  scattered clouds       286.58      67.0         4.6
#
# [500 rows x 14 columns]

# %%
df3['last_update'] = pd.to_datetime(df3.last_update, unit='ms')

# %%
df3.to_csv('full_dataframe.csv')
