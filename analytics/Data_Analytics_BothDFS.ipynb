# %%
import pymysql
from pandas import DataFrame
import pandas as pd 

host   = 'villagebikesdb.c2v2pmaab8cg.us-east-2.rds.amazonaws.com'
port   = 3306
user   = 'ssk'
passwd = 'villagebikes'
db     = 'VillageBikesDB'

cnx    = pymysql.connect(host=host, port=port, user=user, passwd=passwd, db=db)
cur    = cnx.cursor()

query  = """SELECT * FROM weatherData"""
cur.execute(query)

field_names = [i[0] for i in cur.description]
get_data = [xx for xx in cur]

cur.close()
cnx.close()

df1 = DataFrame(get_data)
df1.columns = field_names
len(df1)
# Out:
# 2922

# %%
df1['timestamp'] = pd.to_datetime(df1.timestamp,unit='s')

# %%
df1.head()
# Out:
#             timestamp  weather_id    main       description  temperature  \
# 0 2019-02-21 10:00:00         802  Clouds  scattered clouds       285.13
# 1 2019-02-21 11:30:00         802  Clouds  scattered clouds       285.64
# 2 2019-02-21 12:00:00         802  Clouds  scattered clouds       285.64
# 3 2019-02-21 12:30:00         802  Clouds  scattered clouds       285.64
# 4 2019-02-21 15:00:00         803  Clouds     broken clouds       286.15
#
#    humidity  wind_speed
# 0      76.0         3.1
# 1      71.0         5.1
# 2      71.0         6.2
# 3      66.0         5.7
# 4      62.0         8.2

# %%
df1 = df1.rename(index=str, columns={"timestamp": "last_update"})
df1.head()
# Out:
#           last_update  weather_id    main       description  temperature  \
# 0 2019-02-21 10:00:00         802  Clouds  scattered clouds       285.13
# 1 2019-02-21 11:30:00         802  Clouds  scattered clouds       285.64
# 2 2019-02-21 12:00:00         802  Clouds  scattered clouds       285.64
# 3 2019-02-21 12:30:00         802  Clouds  scattered clouds       285.64
# 4 2019-02-21 15:00:00         803  Clouds     broken clouds       286.15
#
#    humidity  wind_speed
# 0      76.0         3.1
# 1      71.0         5.1
# 2      71.0         6.2
# 3      66.0         5.7
# 4      62.0         8.2

# %%
import pymysql
from pandas import DataFrame
import pandas as pd 

host   = 'villagebikesdb.c2v2pmaab8cg.us-east-2.rds.amazonaws.com'
port   = 3306
user   = 'ssk'
passwd = 'villagebikes'
db     = 'VillageBikesDB'

cnx    = pymysql.connect(host=host, port=port, user=user, passwd=passwd, db=db)
cur    = cnx.cursor()

query  = """SELECT * FROM dynamicData"""
cur.execute(query)

field_names = [i[0] for i in cur.description]
get_data = [xx for xx in cur]

cur.close()
cnx.close()

df2 = DataFrame(get_data)
df2.columns = field_names
len(df2)
# Out:
# 1152794

# %%
df2['last_update'] = pd.to_datetime(df2.last_update,unit='ms')

# %%
df2.head()
# Out:
#    number                name status  bike_stands  available_bikes  \
# 0       2  BLESSINGTON STREET   OPEN           20                3
# 1       2  BLESSINGTON STREET   OPEN           20                3
# 2       2  BLESSINGTON STREET   OPEN           20                3
# 3       2  BLESSINGTON STREET   OPEN           20                4
# 4       2  BLESSINGTON STREET   OPEN           20                4
#
#    available_stands         last_update  banking
# 0                17 2019-02-21 16:47:26        1
# 1                17 2019-02-21 16:57:35        1
# 2                17 2019-02-21 17:07:43        1
# 3                16 2019-02-21 17:17:52        1
# 4                16 2019-02-21 17:24:01        1

# %%
len(df2)
# Out:
# 1152794

# %%
df1.dtypes
# Out:
# last_update    datetime64[ns]
# weather_id              int64
# main                   object
# description            object
# temperature           float64
# humidity              float64
# wind_speed            float64
# dtype: object

# %%
df2.dtypes
# Out:
# number                       int64
# name                        object
# status                      object
# bike_stands                  int64
# available_bikes              int64
# available_stands             int64
# last_update         datetime64[ns]
# banking                      int64
# dtype: object

# %%
df1 = df1.sort_values(by=['last_update'])

# %%
df2 = df2.sort_values(by=['last_update'])

# %%
df2.head()
# Out:
#          number                        name status  bike_stands  \
# 302724       30        PARNELL SQUARE NORTH   OPEN           20
# 1062098     105  GRANGEGORMAN LOWER (NORTH)   OPEN           36
# 586466       55                HATCH STREET   OPEN           36
# 985438       95              ROYAL HOSPITAL   OPEN           40
# 444980       41            HARCOURT TERRACE   OPEN           20
#
#          available_bikes  available_stands         last_update  banking
# 302724                 0                20 2019-02-21 16:45:01        1
# 1062098                9                27 2019-02-21 16:45:05        0
# 586466                 0                36 2019-02-21 16:45:11        0
# 985438                 5                35 2019-02-21 16:45:17        1
# 444980                 1                19 2019-02-21 16:45:25        0

# %%
df3 = pd.merge_asof(df2,df1, on='last_update', direction='nearest')
df3
# Out:
#          number                               name status  bike_stands  \
# 0            30               PARNELL SQUARE NORTH   OPEN           20
# 1           105         GRANGEGORMAN LOWER (NORTH)   OPEN           36
# 2            55                       HATCH STREET   OPEN           36
# 3            95                     ROYAL HOSPITAL   OPEN           40
# 4            41                   HARCOURT TERRACE   OPEN           20
# 5           113               MERRION SQUARE SOUTH   OPEN           40
# 6            61                    HARDWICKE PLACE   OPEN           25
# 7            82                        MOUNT BROWN   OPEN           22
# 8            79                 ECCLES STREET EAST   OPEN           27
# 9            13            FITZWILLIAM SQUARE WEST   OPEN           30
# 10           90                      BENSON STREET   OPEN           40
# 11            2                 BLESSINGTON STREET   OPEN           20
# 12           94         HEUSTON STATION (CAR PARK)   OPEN           40
# 13          106                      RATHDOWN ROAD   OPEN           40
# 14          110                  PHIBSBOROUGH ROAD   OPEN           40
# 15           81       ST. JAMES HOSPITAL (CENTRAL)   OPEN           40
# 16          111               MOUNTJOY SQUARE EAST   OPEN           40
# 17           10                        DAME STREET   OPEN           16
# 18            3                      BOLTON STREET   OPEN           20
# 19          108                      AVONDALE ROAD   OPEN           40
# 20          102                        WESTERN WAY   OPEN           40
# 21           84                    BROOKFIELD ROAD   OPEN           30
# 22           15                   HARDWICKE STREET   OPEN           16
# 23           76                MARKET STREET SOUTH   OPEN           38
# 24           52                   YORK STREET EAST   OPEN           32
# 25           29                  ORMOND QUAY UPPER   OPEN           29
# 26            7                        HIGH STREET   OPEN           29
# 27           87            COLLINS BARRACKS MUSEUM   OPEN           38
# 28          109            BUCKINGHAM STREET LOWER   OPEN           29
# 29           96                    KILMAINHAM LANE   OPEN           30
# ...         ...                                ...    ...          ...
# 1152764      19                      HERBERT PLACE   OPEN           30
# 1152765     107                   CHARLEVILLE ROAD   OPEN           40
# 1152766      75                       JAMES STREET   OPEN           40
# 1152767     112  NORTH CIRCULAR ROAD (O'CONNELL'S)   OPEN           30
# 1152768      39                     WILTON TERRACE   OPEN           20
# 1152769      51                   YORK STREET WEST   OPEN           40
# 1152770      58                  SIR PATRICK DUN'S   OPEN           40
# 1152771      52                   YORK STREET EAST   OPEN           32
# 1152772      94         HEUSTON STATION (CAR PARK)   OPEN           40
# 1152773      31                     PARNELL STREET   OPEN           20
# 1152776               28                 1 2019-04-06 16:34:24        0
# 1152777               14                16 2019-04-06 16:34:29        0
# 1152778                2                21 2019-04-06 16:34:31        0
# 1152779                0                40 2019-04-06 16:34:34        0
# 1152780               16                 0 2019-04-06 16:34:35        1
# 1152781               14                 9 2019-04-06 16:34:36        1
# 1152782                3                37 2019-04-06 16:34:39        1
# 1152783                0                30 2019-04-06 16:34:41        0
# 1152784                5                25 2019-04-06 16:34:43        0
# 1152785               27                 8 2019-04-06 16:34:45        0
# 1152786               16                24 2019-04-06 16:34:48        1
# 1152787                7                33 2019-04-06 16:34:49        0
# 1152788               21                 4 2019-04-06 16:34:51        0
# 1152789               26                 6 2019-04-06 16:34:52        0
# 1152790               14                 6 2019-04-06 16:34:52        0
# 1152791                7                23 2019-04-06 16:34:56        0
# 1152792                1                29 2019-04-06 16:34:59        0
# 1152793                5                35 2019-04-06 16:35:01        1
#
#          weather_id    main    description  temperature  humidity  wind_speed
# 0               803  Clouds  broken clouds       284.15      71.0         6.2
# 1               803  Clouds  broken clouds       284.15      71.0         6.2
# 2               803  Clouds  broken clouds       284.15      71.0         6.2
# 3               803  Clouds  broken clouds       284.15      71.0         6.2
# 4               803  Clouds  broken clouds       284.15      71.0         6.2
# 5               803  Clouds  broken clouds       284.15      71.0         6.2
# 6               803  Clouds  broken clouds       284.15      71.0         6.2
# 7               803  Clouds  broken clouds       284.15      71.0         6.2
# 8               803  Clouds  broken clouds       284.15      71.0         6.2
# 9               803  Clouds  broken clouds       284.15      71.0         6.2
# 10              803  Clouds  broken clouds       284.15      71.0         6.2
# 11              803  Clouds  broken clouds       284.15      71.0         6.2
# 12              803  Clouds  broken clouds       284.15      71.0         6.2
# 13              803  Clouds  broken clouds       284.15      71.0         6.2
# 14              803  Clouds  broken clouds       284.15      71.0         6.2
# 15              803  Clouds  broken clouds       284.15      71.0         6.2
# 16              803  Clouds  broken clouds       284.15      71.0         6.2
# 17              803  Clouds  broken clouds       284.15      71.0         6.2
# 18              803  Clouds  broken clouds       284.15      71.0         6.2
# 19              803  Clouds  broken clouds       284.15      71.0         6.2
# 20              803  Clouds  broken clouds       284.15      71.0         6.2
# 21              803  Clouds  broken clouds       284.15      71.0         6.2
# 22              803  Clouds  broken clouds       284.15      71.0         6.2
# 23              803  Clouds  broken clouds       284.15      71.0         6.2
# 24              803  Clouds  broken clouds       284.15      71.0         6.2
# 25              803  Clouds  broken clouds       284.15      71.0         6.2
# 26              803  Clouds  broken clouds       284.15      71.0         6.2
# 27              803  Clouds  broken clouds       284.15      71.0         6.2
# 28              803  Clouds  broken clouds       284.15      71.0         6.2
# 29              803  Clouds  broken clouds       284.15      71.0         6.2
# ...             ...     ...            ...          ...       ...         ...
# 1152764         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152765         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152766         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152767         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152768         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152769         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152770         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152771         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152772         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152773         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152774         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152775         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152776         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152777         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152778         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152779         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152780         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152781         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152782         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152783         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152784         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152785         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152786         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152787         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152788         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152789         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152790         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152791         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152792         803  Clouds  broken clouds       283.04      71.0         3.1
# 1152793         803  Clouds  broken clouds       283.04      71.0         3.1
#
# [1152794 rows x 14 columns]

# %%
df3['last_update'] = pd.to_datetime(df3.last_update, unit='ms')

# %%
df3.to_csv('full_dataframe.csv')
