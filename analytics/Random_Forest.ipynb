# %%
import pandas as pd

# %%
df = pd.read_csv('full_dataframe.csv')

# %%
df
# Out:
#         Unnamed: 0  number                               name status  \
# 0                0      30               PARNELL SQUARE NORTH   OPEN
# 1                1     105         GRANGEGORMAN LOWER (NORTH)   OPEN
# 2                2      55                       HATCH STREET   OPEN
# 3                3      95                     ROYAL HOSPITAL   OPEN
# 4                4      41                   HARCOURT TERRACE   OPEN
# 5                5     113               MERRION SQUARE SOUTH   OPEN
# 6                6      61                    HARDWICKE PLACE   OPEN
# 7                7      82                        MOUNT BROWN   OPEN
# 8                8      79                 ECCLES STREET EAST   OPEN
# 9                9      13            FITZWILLIAM SQUARE WEST   OPEN
# 10              10      90                      BENSON STREET   OPEN
# 11              11       2                 BLESSINGTON STREET   OPEN
# 12              12      94         HEUSTON STATION (CAR PARK)   OPEN
# 13              13     106                      RATHDOWN ROAD   OPEN
# 14              14     110                  PHIBSBOROUGH ROAD   OPEN
# 15              15      81       ST. JAMES HOSPITAL (CENTRAL)   OPEN
# 16              16     111               MOUNTJOY SQUARE EAST   OPEN
# 17              17      10                        DAME STREET   OPEN
# 18              18       3                      BOLTON STREET   OPEN
# 19              19     108                      AVONDALE ROAD   OPEN
# 20              20     102                        WESTERN WAY   OPEN
# 21              21      84                    BROOKFIELD ROAD   OPEN
# 22              22      15                   HARDWICKE STREET   OPEN
# 23              23      76                MARKET STREET SOUTH   OPEN
# 24              24      52                   YORK STREET EAST   OPEN
# 25              25      29                  ORMOND QUAY UPPER   OPEN
# 26              26       7                        HIGH STREET   OPEN
# 27              27      87            COLLINS BARRACKS MUSEUM   OPEN
# 28              28     109            BUCKINGHAM STREET LOWER   OPEN
# 29              29      96                    KILMAINHAM LANE   OPEN
# ...            ...     ...                                ...    ...
# 812459      812459      61                    HARDWICKE PLACE   OPEN
# 812460      812460     113               MERRION SQUARE SOUTH   OPEN
# 812461      812461      60                NORTH CIRCULAR ROAD   OPEN
# 812462      812462       2                 BLESSINGTON STREET   OPEN
# 812463      812463      14                FOWNES STREET UPPER   OPEN
# 812464      812464      67                          THE POINT   OPEN
# 812465      812465      53                       NEWMAN HOUSE   OPEN
# 812466      812466      69                   GRAND CANAL DOCK   OPEN
# 812467      812467      68                       HANOVER QUAY   OPEN
# 812468      812468      78                     MATER HOSPITAL   OPEN
# 812469      812469      19                      HERBERT PLACE   OPEN
# 812470      812470      13            FITZWILLIAM SQUARE WEST   OPEN
# 812471      812471      86                    PARKGATE STREET   OPEN
# 812472      812472      42                   SMITHFIELD NORTH   OPEN
# 812473      812473      23                       CUSTOM HOUSE   OPEN
# 812474      812474      35                         SMITHFIELD   OPEN
# 812475      812475      83                         EMMET ROAD   OPEN
# 812476      812476      55                       HATCH STREET   OPEN
# 812477      812477      66                   NEW CENTRAL BANK   OPEN
# 812478      812478      91                    SOUTH DOCK ROAD   OPEN
# 812479      812479      96                    KILMAINHAM LANE   OPEN
# 812471        1         802  Clouds  scattered clouds       284.50      62.0
# 812472        1         802  Clouds  scattered clouds       284.50      62.0
# 812473        1         802  Clouds  scattered clouds       284.50      62.0
# 812474        0         802  Clouds  scattered clouds       284.50      62.0
# 812475        0         802  Clouds  scattered clouds       284.50      62.0
# 812476        0         802  Clouds  scattered clouds       284.50      62.0
# 812477        0         802  Clouds  scattered clouds       284.50      62.0
# 812478        0         802  Clouds  scattered clouds       284.50      62.0
# 812479        0         802  Clouds  scattered clouds       284.50      62.0
# 812480        1         802  Clouds  scattered clouds       284.50      62.0
# 812481        0         802  Clouds  scattered clouds       284.50      62.0
# 812482        0         802  Clouds  scattered clouds       284.50      62.0
# 812483        0         802  Clouds  scattered clouds       284.50      62.0
# 812484        0         802  Clouds  scattered clouds       284.50      62.0
# 812485        0         802  Clouds  scattered clouds       284.50      62.0
# 812486        1         802  Clouds  scattered clouds       284.50      62.0
# 812487        0         802  Clouds  scattered clouds       284.50      62.0
# 812488        1         802  Clouds  scattered clouds       284.50      62.0
#
#         wind_speed
# 0              6.2
# 1              6.2
# 2              6.2
# 3              6.2
# 4              6.2
# 5              6.2
# 6              6.2
# 7              6.2
# 8              6.2
# 9              6.2
# 10             6.2
# 11             6.2
# 12             6.2
# 13             6.2
# 14             6.2
# 15             6.2
# 16             6.2
# 17             6.2
# 18             6.2
# 19             6.2
# 20             6.2
# 21             6.2
# 22             6.2
# 23             6.2
# 24             6.2
# 25             6.2
# 26             6.2
# 27             6.2
# 28             6.2
# 29             6.2
# ...            ...
# 812459         4.6
# 812460         4.6
# 812461         4.6
# 812462         4.6
# 812463         4.6
# 812464         4.6
# 812465         4.6
# 812466         4.6
# 812467         4.6
# 812468         4.6
# 812469         4.6
# 812470         4.6
# 812471         4.6
# 812472         4.6
# 812473         4.6
# 812474         4.6
# 812475         4.6
# 812476         4.6
# 812477         4.6
# 812478         4.6
# 812479         4.6
# 812480         4.6
# 812481         4.6
# 812482         4.6
# 812483         4.6
# 812484         4.6
# 812485         4.6
# 812486         4.6
# 812487         4.6
# 812488         4.6
#
# [812489 rows x 15 columns]

# %%
df['description'].value_counts()
# Out:
# broken clouds                   204962
# light rain                      172416
# few clouds                       77505
# scattered clouds                 74571
# moderate rain                    63231
# shower rain                      55117
# clear sky                        43515
# light intensity shower rain      37147
# mist                             28452
# heavy intensity rain             18499
# fog                              14335
# light intensity drizzle          13787
# light intensity drizzle rain      3302
# very heavy rain                   3052
# snow                              1458
# shower sleet                      1140
# Name: description, dtype: int64

# %%
df['main'].value_counts()
# Out:
# Clouds     357038
# Rain       349462
# Clear       43515
# Mist        28452
# Drizzle     17089
# Fog         14335
# Snow         2598
# Name: main, dtype: int64

# %%
for col in df[['description']].columns:
    if [df['description']=='clear sky']:
        df['description'].replace('clear sky',1, inplace=True)
    if[df['description']=='few clouds']:
        df['description'].replace('few clouds', 2, inplace=True)
    if[df['description']=='scattered clouds']:
        df['description'].replace('scattered clouds',3, inplace=True)
    if [df['description']=='broken clouds']:
        df['description'].replace('broken clouds',4, inplace=True)
    if [df['description']=='fog']:
        df['description'].replace('fog',5, inplace=True)
    if [df['description']=='mist']:
        df['description'].replace('mist',6, inplace=True)
    if [df['description']=='light intensity drizzle']:
        df['description'].replace('light intensity drizzle',7, inplace=True)
    if [df['description']=='light intensity drizzle rain']:
        df['description'].replace('light intensity drizzle rain',8, inplace=True)
    if [df['description']=='light intensity shower rain']:
        df['description'].replace('light intensity shower rain',9, inplace=True)
    if [df['description']=='shower rain']:
        df['description'].replace('shower rain',10, inplace=True)
    if [df['description']=='heavy intensity rain']:
        df['description'].replace('heavy intensity rain',11, inplace=True)
    if [df['description']=='light rain']:
        df['description'].replace('light rain',12, inplace=True)
    if [df['description']=='moderate rain']:
        df['description'].replace('moderate rain',13, inplace=True)
    if [df['description']=='very heavy rain']:
        df['description'].replace('very heavy rain',14, inplace=True)
    if [df['description']=='shower sleet']:
        df['description'].replace('shower sleet',15, inplace=True)
    if [df['description']=='snow']:
        df['description'].replace('snow',16, inplace=True)

# %%
df['description'].value_counts()
# Out:
# 4     204962
# 12    172416
# 2      77505
# 3      74571
# 13     63231
# 10     55117
# 1      43515
# 9      37147
# 6      28452
# 11     18499
# 5      14335
# 7      13787
# 8       3302
# 14      3052
# 16      1458
# 15      1140
# Name: description, dtype: int64

# %%
df
# Out:
#         Unnamed: 0  number                               name status  \
# 0                0      30               PARNELL SQUARE NORTH   OPEN
# 1                1     105         GRANGEGORMAN LOWER (NORTH)   OPEN
# 2                2      55                       HATCH STREET   OPEN
# 3                3      95                     ROYAL HOSPITAL   OPEN
# 4                4      41                   HARCOURT TERRACE   OPEN
# 5                5     113               MERRION SQUARE SOUTH   OPEN
# 6                6      61                    HARDWICKE PLACE   OPEN
# 7                7      82                        MOUNT BROWN   OPEN
# 8                8      79                 ECCLES STREET EAST   OPEN
# 9                9      13            FITZWILLIAM SQUARE WEST   OPEN
# 10              10      90                      BENSON STREET   OPEN
# 11              11       2                 BLESSINGTON STREET   OPEN
# 12              12      94         HEUSTON STATION (CAR PARK)   OPEN
# 13              13     106                      RATHDOWN ROAD   OPEN
# 14              14     110                  PHIBSBOROUGH ROAD   OPEN
# 15              15      81       ST. JAMES HOSPITAL (CENTRAL)   OPEN
# 16              16     111               MOUNTJOY SQUARE EAST   OPEN
# 17              17      10                        DAME STREET   OPEN
# 18              18       3                      BOLTON STREET   OPEN
# 19              19     108                      AVONDALE ROAD   OPEN
# 20              20     102                        WESTERN WAY   OPEN
# 21              21      84                    BROOKFIELD ROAD   OPEN
# 22              22      15                   HARDWICKE STREET   OPEN
# 23              23      76                MARKET STREET SOUTH   OPEN
# 24              24      52                   YORK STREET EAST   OPEN
# 25              25      29                  ORMOND QUAY UPPER   OPEN
# 26              26       7                        HIGH STREET   OPEN
# 27              27      87            COLLINS BARRACKS MUSEUM   OPEN
# 28              28     109            BUCKINGHAM STREET LOWER   OPEN
# 29              29      96                    KILMAINHAM LANE   OPEN
# ...            ...     ...                                ...    ...
# 812459      812459      61                    HARDWICKE PLACE   OPEN
# 812460      812460     113               MERRION SQUARE SOUTH   OPEN
# 812461      812461      60                NORTH CIRCULAR ROAD   OPEN
# 812462      812462       2                 BLESSINGTON STREET   OPEN
# 812463      812463      14                FOWNES STREET UPPER   OPEN
# 812464      812464      67                          THE POINT   OPEN
# 812465      812465      53                       NEWMAN HOUSE   OPEN
# 812466      812466      69                   GRAND CANAL DOCK   OPEN
# 812467      812467      68                       HANOVER QUAY   OPEN
# 812468      812468      78                     MATER HOSPITAL   OPEN
# 812469      812469      19                      HERBERT PLACE   OPEN
# 812470      812470      13            FITZWILLIAM SQUARE WEST   OPEN
# 812471      812471      86                    PARKGATE STREET   OPEN
# 812472      812472      42                   SMITHFIELD NORTH   OPEN
# 812473      812473      23                       CUSTOM HOUSE   OPEN
# 812474      812474      35                         SMITHFIELD   OPEN
# 812475      812475      83                         EMMET ROAD   OPEN
# 812476      812476      55                       HATCH STREET   OPEN
# 812477      812477      66                   NEW CENTRAL BANK   OPEN
# 812478      812478      91                    SOUTH DOCK ROAD   OPEN
# 812479      812479      96                    KILMAINHAM LANE   OPEN
# 812480      812480      32                      PEARSE STREET   OPEN
# 812481      812481      41                   HARCOURT TERRACE   OPEN
# 812482      812482      21              LEINSTER STREET SOUTH   OPEN
# 812483      812483      49                       GUILD STREET   OPEN
# 812484      812484      62                        LIME STREET   OPEN
# 812485      812485      74                 OLIVER BOND STREET   OPEN
# 812486      812486      33  PRINCES STREET / O'CONNELL STREET   OPEN
# 812487      812487       3                      BOLTON STREET   OPEN
# 812488      812488      10                        DAME STREET   OPEN
#
#         bike_stands  available_bikes  available_stands          last_update  \
# 0                20                0                20  2019-02-21 16:45:01
# 1                36                9                27  2019-02-21 16:45:05
# 2                36                0                36  2019-02-21 16:45:11
# 3                40                5                35  2019-02-21 16:45:17
# 4                20                1                19  2019-02-21 16:45:25
# 5                40               33                 7  2019-02-21 16:45:32
# 6                25                0                25  2019-02-21 16:45:41
# 7                22                0                22  2019-02-21 16:45:56
# 8                27                0                27  2019-02-21 16:46:31
# 9                30               18                11  2019-02-21 16:47:08
# 10               40               19                21  2019-02-21 16:47:20
# 11               20                3                17  2019-02-21 16:47:26
# 12               40                0                40  2019-02-21 16:47:58
# 13               40                3                37  2019-02-21 16:48:11
# 14               40                1                39  2019-02-21 16:48:20
# 15               40                0                40  2019-02-21 16:48:22
# 16               40                2                38  2019-02-21 16:48:28
# 17               16                0                16  2019-02-21 16:48:59
# 18               20                0                20  2019-02-21 16:49:04
# 19               40                1                38  2019-02-21 16:49:10
# 20               40                7                33  2019-02-21 16:49:25
# 21               30                1                29  2019-02-21 16:49:28
# 22            0         803  Clouds            4       284.15      71.0
# 23            0         803  Clouds            4       284.15      71.0
# 24            0         803  Clouds            4       284.15      71.0
# 25            1         803  Clouds            4       284.15      71.0
# 26            1         803  Clouds            4       284.15      71.0
# 27            1         803  Clouds            4       284.15      71.0
# 28            0         803  Clouds            4       284.15      71.0
# 29            0         803  Clouds            4       284.15      71.0
# ...         ...         ...     ...          ...          ...       ...
# 812459        1         802  Clouds            3       284.50      62.0
# 812460        1         802  Clouds            3       284.50      62.0
# 812461        0         802  Clouds            3       284.50      62.0
# 812462        1         802  Clouds            3       284.50      62.0
# 812463        0         802  Clouds            3       284.50      62.0
# 812464        0         802  Clouds            3       284.50      62.0
# 812465        0         802  Clouds            3       284.50      62.0
# 812466        0         802  Clouds            3       284.50      62.0
# 812467        1         802  Clouds            3       284.50      62.0
# 812468        0         802  Clouds            3       284.50      62.0
# 812469        0         802  Clouds            3       284.50      62.0
# 812470        0         802  Clouds            3       284.50      62.0
# 812471        1         802  Clouds            3       284.50      62.0
# 812472        1         802  Clouds            3       284.50      62.0
# 812473        1         802  Clouds            3       284.50      62.0
# 812474        0         802  Clouds            3       284.50      62.0
# 812475        0         802  Clouds            3       284.50      62.0
# 812476        0         802  Clouds            3       284.50      62.0
# 812477        0         802  Clouds            3       284.50      62.0
# 812478        0         802  Clouds            3       284.50      62.0
# 812479        0         802  Clouds            3       284.50      62.0
# 812480        1         802  Clouds            3       284.50      62.0
# 812481        0         802  Clouds            3       284.50      62.0
# 812482        0         802  Clouds            3       284.50      62.0
# 812483        0         802  Clouds            3       284.50      62.0
# 812484        0         802  Clouds            3       284.50      62.0
# 812485        0         802  Clouds            3       284.50      62.0
# 812486        1         802  Clouds            3       284.50      62.0
# 812487        0         802  Clouds            3       284.50      62.0
# 812488        1         802  Clouds            3       284.50      62.0
#
#         wind_speed
# 0              6.2
# 1              6.2
# 2              6.2
# 3              6.2
# 4              6.2
# 5              6.2
# 6              6.2
# 7              6.2
# 8              6.2
# 9              6.2
# 10             6.2
# 11             6.2
# 12             6.2
# 13             6.2
# 14             6.2
# 15             6.2
# 16             6.2
# 17             6.2
# 18             6.2
# 19             6.2
# 20             6.2
# 21             6.2
# 22             6.2
# 23             6.2
# 24             6.2
# 25             6.2
# 26             6.2
# 27             6.2
# 28             6.2
# 29             6.2
# ...            ...
# 812459         4.6
# 812460         4.6
# 812461         4.6
# 812462         4.6
# 812463         4.6
# 812464         4.6
# 812465         4.6
# 812466         4.6
# 812467         4.6
# 812468         4.6
# 812469         4.6
# 812470         4.6
# 812471         4.6
# 812472         4.6
# 812473         4.6
# 812474         4.6
# 812475         4.6
# 812476         4.6
# 812477         4.6
# 812478         4.6
# 812479         4.6
# 812480         4.6
# 812481         4.6
# 812482         4.6
# 812483         4.6
# 812484         4.6
# 812485         4.6
# 812486         4.6
# 812487         4.6
# 812488         4.6
#
# [812489 rows x 15 columns]
